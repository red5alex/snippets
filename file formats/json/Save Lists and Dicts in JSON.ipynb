# %%
sample = [{"name" : "Alex",
           "age": 37,
           "height":1.76},
          {"name" : "Caro",
           "age": 25,
           "height":1.50}]

import json
with open('test.json', 'w') as jf:
    json.dump(sample, jf)

# %%
import json
json.load(open('test.json'))
# Out:
# [{u'age': 37, u'height': 1.76, u'name': u'Alex'},
#  {u'age': 25, u'height': 1.5, u'name': u'Caro'}]
